# %%
x = 153

sum1 = 0
while x > 0:
    n = x%10 
    sum1 = sum1 + n**3
    x = x//10
    
print(sum1)
# Out:
# 153

# %%
n = int(input("please enter the any number to find it is armstrong or not"))


def armstrong1(x):
    temp = x
    sum1 = 0
    while x > 0:
        n = x%10 
        sum1 = sum1 + n**3
        x = x//10
        
    if temp == sum1:
        print("the given number is a armstrong ", temp)
    else:
        print("the given number is not a  armstrong ")


armstrong1(n)
# Out:
# please enter the any number to find it is armstrong or not153
# the given number is a armstrong  153

# %%
#n = int(input("please enter the any number to find it is armstrong or not"))


def armstrong1(x):
    global a
    temp = x
    sum1 = 0
    while x > 0:
        n = x%10 
        sum1 = sum1 + n**3
        x = x//10
        
    if temp == sum1:
        print("the given number is a armstrong ", temp)
        a.append(sum1)
    else:
        print("the given number is not a  armstrong ")

        
a = []
for i in range(1,1001):
    armstrong1(i)
# Out:
# the given number is a armstrong  1
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# the given number is not a  armstrong
# ...

# %%
print(a)
# Out:
# [1, 153, 370, 371, 407]
